# %% [markdown]
# ## Introdução ao Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Plot

# %%
# Descreve as aletrações nos dados ao longo do tempo
x = np.array([1, 2, 3, 4])
y = x*2 # eixo y do gráfico 1
y2 = x**2 # eixo y do gráfico 2

plt.xlabel('Valores de X')
plt.ylabel('Valores de Y')

plt.plot(x, y, 's:r', x, y2, 'o-b', linewidth = 3, markersize = 20)
# Out:
# [<matplotlib.lines.Line2D at 0x1505654fe90>,
#  <matplotlib.lines.Line2D at 0x1505660a190>]

# %%
# Utilizando o conceito de subplot
plt.subplot(1, 2, 1)
plt.title('Função Linear')
plt.plot(x, y, 's:r')

plt.subplot(1, 2, 2)
plt.title('Função Exponencial')
plt.plot(x, y2, 'o-b')

# %% [markdown]
# Gráfico em Barras

# %%
# Importando o dataset
df = pd.read_csv('paises.csv', delimiter=';')

# Extraindo as colunas
print(df.columns)

# Extraindo os 5 maiores GDP do dataset
dfBiggestGDP = df.nlargest(5, 'GDP ($ per capita)')

# Extraindo o nome destes paises
eixo_x = dfBiggestGDP['Country']
eixo_y = dfBiggestGDP['GDP ($ per capita)']

# Traçando o gráfico
plt.bar(eixo_x, eixo_y, color='green')
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')
# <BarContainer object of 5 artists>

# %% [markdown]
# Gráfico em Torta

# %%
print(df.columns)

# Extraindo países que não tem costa marítma
dfNoCoast = df[df['Coastline (coast/area ratio)']==0]

withCoast = len(df) - len(dfNoCoast)
withoutCoast = len(dfNoCoast)

# Traçando gráfico em torta
plt.pie(x=[withCoast, withoutCoast], labels=['% Países com Costa', '%  Países sem Costa'], autopct='%1.1f%%')
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP ($ per capita)', 'Literacy (%)', 'Phones (per 1000)', 'Arable (%)',
#        'Crops (%)', 'Other (%)', 'Climate', 'Birthrate', 'Deathrate',
#        'Agriculture', 'Industry', 'Service'],
#       dtype='object')
# ([<matplotlib.patches.Wedge at 0x1505a390ad0>,
#   <matplotlib.patches.Wedge at 0x1505b1b6390>],
#  [Text(-0.9022784529469765, 0.6292007575866474, '% Países com Costa'),
#   Text(0.9022785079534524, -0.6292006787069543, '%  Países sem Costa')],
#  [Text(-0.49215188342562344, 0.3432004132290804, '80.6%'),
#   Text(0.49215191342915576, -0.3432003702037932, '19.4%')])
